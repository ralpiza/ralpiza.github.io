# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ralpiza/ralpiza/blob/main/examples/notebook/PATH_TO_NOTEBOOK.ipynb)

# %%
print("Hello, World")
# Out:
# Hello, World
